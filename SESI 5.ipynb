# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')
print(len(df))
print(df.shape)
# Out:
# 126314
# (126314, 23)

# %%
#melihat 5 baris data pertama dengan .head()
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
#menampilkan seluruh kolom
pd.set_option("display.max.columns",None)
#mengatur agar hanya enampilkan 2 angka desimal
pd.set_option("display.precision",2)

# %%
#melihat kembali tampilan 5 baris pertama setelah di atur
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
#melihat tampilan 5 baris terakhir
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
#melihat tampilan n baris pertama
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# ...

# %%
#menampilkan semua kolom dan tipe data pada file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
#melihat rangkuman dari setiap kolom 
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
#mengeksplorasi data
#contoh: memeriksa seberapa sering nilai muncul dalam kolom
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# TRH      60
# DTF      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
#melihat data berdasarkan seleksi
df.loc[df['fran_id']=='Lakers','team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['fran_id']=='Lakers','date_game'].max()
# Out:
# '6/9/2009'

# %%
df.loc[df['team_id']=='MNL','date_game'].min()
# Out:
# '1/1/1949'

# %%
df.loc[df['fran_id']=='Warriors','team_id'].value_counts()
# Out:
# GSW    3701
# PHW    1179
# SFW     777
# Name: team_id, dtype: int64

# %%
df.loc[df['team_id']=='SFW','date_game'].agg(('min','max'))
# Out:
# min    1/1/1965
# max    4/8/1967
# Name: date_game, dtype: object

# %%
#mencari banyaknya poin yang dicetak Boston Celtics 'BOS'
df.loc[df['team_id']=='BOS','pts'].sum()
# Out:
# 626484

# %%
#membuat objek series menggunakan list
revenues=pd.Series([5555, 7000, 1980,2005])
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# 3    2005
# dtype: int64

# %%
print(revenues.values)
print(revenues.index)
# Out:
# [5555 7000 1980 2005]
# RangeIndex(start=0, stop=4, step=1)

# %%
city_revenues=pd.Series([4200,8000,6500],
                        index=['Amsterdam','Toronto','Tokyo'])
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues['Amsterdam']
# Out:
# 4200

# %%
#membuat series dengan indeks label dari dicionary Python
city_employee_count=pd.Series({'Amsterdam':5,'Tokyo':8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
'Tokyo' in city_employee_count
# Out:
# True

# %%
#Menggabukan objek series kedalam data frame dengan dictionary
city_data=pd.DataFrame({'revenue':city_revenues,
                        'employee_count':city_employee_count})
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
#melihat index baru dari gabungan 2 serie pada DataFrame
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
#melihat nilai dari datFrame
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
#melihat index berdasar baris dan kolom
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
'Amsterdam' in city_data
# Out:
# False

# %%
'revenue' in city_data
# Out:
# True

# %%
print(city_data['revenue'])
print(city_data['employee_count'])
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64
# Amsterdam    5.0
# Tokyo        8.0
# Toronto      NaN
# Name: employee_count, dtype: float64

# %%
#melihat range index dari file csv
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
df.keys()
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df['team_id']
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
'pts' in df.keys()
# Out:
# True

# %%
'pts' in df
# Out:
# True

# %%
colors=pd.Series(['red','purple','blue','green','yellow'],
                 index=[1,2,3,5,8])

# %%
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors[1]
# Out:
# 'red'

# %%
#menggunakan .loc dan .iloc
#.loc mengacu pada label indeks
#.iloc mengacu pada posisi indeks
print(colors.loc[2])
print(colors.iloc[2])
print(colors.loc[1:3])
print(colors.iloc[1:3])
print(colors.iloc[-1])
# Out:
# purple
# blue
# 1       red
# 2    purple
# 3      blue
# dtype: object
# 2    purple
# 3      blue
# dtype: object
# yellow

# %%
#mengakses elemen pada dataFrame
city_data['revenue']
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
#jika nama kolom string bisa diakses dengan dot notation
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
toys=pd.DataFrame([{"name":"ball","shape":"sphere"},
                 {"name":"Rubik's cube","shape":"cube"}])
toys
# Out:
#            name   shape
# 0          ball  sphere
# 1  Rubik's cube    cube

# %%
#jika nama kolom sama dengan nama method maka,
#hasil akan memproses method
toys.shape
# Out:
# (2, 2)

# %%
#operasi pengindeksan akan menghasilkan isi kolo
toys['shape']
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
#.loc dan .iloc pada dataframe
print(city_data.loc['Tokyo'])
print(city_data.iloc[0])
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.loc['Tokyo':'Toronto']
# Out:
#          revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
df.iloc[-2]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i               1700.7391
# elo_n               1692.0859
# win_equiv           59.290245
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i           1813.6349
# opp_elo_n           1822.2881
# game_location               H
# game_result                 L
# forecast              0.48145
# notes                     NaN
# Name: 126312, dtype: object

# %%
city_data.loc['Amsterdam':'Tokyo','revenue']
# Out:
# Amsterdam    4200
# Tokyo        6500
# Name: revenue, dtype: int64

# %%
df.loc[126300:,'date_game':'pts']
# Out:
#         date_game  seasongame  is_playoffs team_id    fran_id  pts
# 126300  5/27/2015          99            1     HOU    Rockets   90
# 126301  5/27/2015          97            1     GSW   Warriors  104
# 126302   6/4/2015          97            1     CLE  Cavaliers  100
# 126303   6/4/2015          98            1     GSW   Warriors  108
# 126304   6/7/2015          98            1     CLE  Cavaliers   95
# 126305   6/7/2015          99            1     GSW   Warriors   93
# 126306   6/9/2015         100            1     GSW   Warriors   91
# 126307   6/9/2015          99            1     CLE  Cavaliers   96
# 126308  6/11/2015         101            1     GSW   Warriors  103
# 126309  6/11/2015         100            1     CLE  Cavaliers   82
# 126310  6/14/2015         102            1     GSW   Warriors  104
# 126311  6/14/2015         101            1     CLE  Cavaliers   91
# 126312  6/16/2015         102            1     CLE  Cavaliers   97
# ...

# %%
df.loc[126305:,['team_id','pts']]
# Out:
#        team_id  pts
# 126305     GSW   93
# 126306     GSW   91
# 126307     CLE   96
# 126308     GSW  103
# 126309     CLE   82
# 126310     GSW  104
# 126311     CLE   91
# 126312     CLE   97
# 126313     GSW  105

# %%
#membuat dataframe baru dari data lama
current_decade=df[df['year_id']>2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
games_with_notes=df[df['notes'].notnull()]
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
games_with_notes.shape
# Out:
# (5424, 23)

# %%
games_with_notes=df[df['notes'].notna()]
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
#mengubah object menjadi string dan memfilter data yg berakhiran 'ers'
ers=df[df['fran_id'].str.endswith('ers')]
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# 7                1            0     PRO  Steamrollers  ...  41.540619     BOS
# ...

# %%
#pencarian untuk game Baltimore dimana kedua tim mencetak >100 poin
#dan harus mengecualikan duplikasi
df[(df['_iscopy']==0)&(df['pts']>100)&
   (df['opp_pts']>100)&(df['team_id']=='BLB')]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  ...  win_equiv  opp_id  opp_fran  \
# 1726            0     BLB  Baltimore  ...  38.557545     MNL    Lakers
# 4890            0     BLB  Baltimore  ...  25.797792     BOS   Celtics
# 4909            0     BLB  Baltimore  ...  24.876236     MNL    Lakers
# 5208            0     BLB  Baltimore  ...  19.579676     NYK    Knicks
# 5825            0     BLB  Baltimore  ...  20.736986     BOS   Celtics
#
# ...

# %%
#Menemukan data tim dari Los Angeles yang bertanding dilapangan lain
#pada tahun 1992, kedua tim dimulai dengan huruf LA
df[(df['team_id'].str.startswith('LA'))&(df['year_id']==1992)
   &(df['notes']).notna()]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  ...  win_equiv  opp_id      opp_fran  \
# 68901            1     LAC  Clippers  ...  47.888252     UTA          Jazz
# 68903            1     LAL    Lakers  ...  39.395412     POR  Trailblazers
#
#        opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 68901      107  1647.5092  1638.4095              H            W  0.499125
# 68903      102  1655.1210  1670.3677              H            L  0.406874
#
#                                             notes
# 68901  at Anaheim, CA (Anaheim Convention Center)
# 68903                            at Las Vegas, NV
#
# [2 rows x 23 columns]

# %%
#groping dan aggregating data
city_revenues=pd.Series([4200,8000,6500],
                        index=['Amsterdam','Toronto','Tokyo'])
print(city_revenues.sum())
print(city_revenues.max())
print(city_revenues.min())
print(city_revenues.mean())
# Out:
# 18700
# 8000
# 4200
# 6233.333333333333

# %%
points=df['pts']
points.sum()
# Out:
# 12976235

# %%
totalPoin=df.groupby('fran_id',sort=False)['pts'].sum()
#sort= False artinya data tidak diurutkan
totalPoin
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df[(df['fran_id'] =='Spurs')&
   (df['year_id']>2010)].groupby(['year_id',
                                  'game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
#kemenangan dan kekalahan golden state warriors 2015
df[(df['fran_id']=='Warriors')&
  (df['year_id']==2015)].groupby(['is_playoffs','game_result'])['game_id'].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
#membuat salinan data
nba=df.copy()

# %%
nba.shape
# Out:
# (126314, 23)

# %%
#membuat kolom baru pada salinan
nba["difference"]=df.pts-df.opp_pts
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba['difference'].max()
# Out:
# 68

# %%
#mengganti nama kolom 
renamed_nba=nba.rename(columns={'game_result':'result',
                                'game_location':'location'})
renamed_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
pd.set_option('display.max.columns',None)
pd.set_option('display.precision',2)

# %%
#menghapus kolom
elo_columns=['elo_i','elo_n','opp_elo_i','opp_elo_n']
nba.drop(elo_columns, inplace=True, axis=1)

# %%
nba.shape
# Out:
# (126314, 20)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  object
#  16  game_result    126314 non-null  object
# ...

# %%
#mengkonvesi tipe data
nba['date_game']=pd.to_datetime(nba['date_game'])

# %%
#melihat berapa banyak nilai yang berbeda
nba['game_location'].nunique()
# Out:
# 3

# %%
nba['game_location'].value_counts()
# Out:
# A    63138
# H    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba['game_location']=pd.Categorical(nba['game_location'])

# %%
nba['game_location'].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
# ...

# %%
#menghapus baris yang mengandung nilai null
rows_without_missing_data=nba.dropna()
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
data_without_missing_columns=nba.dropna(axis=1)
data_without_missing_columns.shape
# Out:
# (126314, 19)

# %%
data_with_default_notes=nba.copy()
data_with_default_notes['notes'].fillna(
    value='no notes at all',
    inplace=True)

# %%
data_with_default_notes['notes'].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %%
nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts      win_equiv        opp_pts  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982      41.707889     102.729982
# std         0.244499      14.814845      10.627332      14.814845
# min         0.000000       0.000000      10.152501       0.000000
# ...

# %%
nba[nba['pts']==0]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, win_equiv, opp_id, opp_fran, opp_pts, game_location, game_result, forecast, notes, difference]
# Index: []

# %%
baris0=nba.loc[26684]
nba.drop(26684, inplace=True, axis=0)

# %%
nba.shape
# Out:
# (126313, 20)

# %%
nba[(nba['pts']>nba['opp_pts'])&
   (nba['game_result'] != 'W')].empty
# Out:
# True

# %%
nba[(nba['pts']<nba['opp_pts'])&(nba['game_result'] !='L')].empty
# Out:
# True

# %%
further_city_data=pd.DataFrame({'revenue':[7000,3400],
                               'employee_count':[2,2]},
                              index=['New York','Barcelona'])

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
#menggabungkan dua dataframe dengan .concat()
all_city_data=pd.concat([city_data,further_city_data],
                       sort=False)

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries=pd.DataFrame({'country':['Holland',
                                       'Japan',
                                        'Holland',
                                      'Canada',
                                      'Spain'],
                           'Capital':[1,1,0,0,0]},
                          index=['Amsterdam','Tokyo',
                                'Rotterdam','Toronto','Barcelona'])
city_countries
# Out:
#            country  Capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
#menggabungkan kolom pada dataframe
cities=pd.concat([all_city_data, city_countries],
                 axis=1, sort=False)
cities
# Out:
#            revenue  employee_count  country  Capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
#hanya menggabungkan kota yang muncul pada kedua dataframe
pd.concat([all_city_data, city_countries], axis=1, join='inner')
# Out:
#            revenue  employee_count  country  Capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
countries=pd.DataFrame({'population_millions':[17,127,37],
                       'continent':['Europe','Asia','North America']
                       },index=['Holland','Japan', 'Canada'])
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
cities
# Out:
#            revenue  employee_count  country  Capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
#implementasi operasi gabungan dengan .merge()
pd.merge(cities, countries, left_on='country',right_index=True)
# Out:
#            revenue  employee_count  country  Capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
#memasukan semua kota dalam hasil
pd.merge(cities, countries, left_on='country',
         right_index=True, how='left')
# Out:
#            revenue  employee_count  country  Capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %%
nba[nba['fran_id']=='Knicks'].groupby('year_id')['pts'].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba['fran_id'].value_counts().head(10).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='fran_id'>

# %%
nba['fran_id'].value_counts().head(10)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: fran_id, dtype: int64

# %%
nba['fran_id'].value_counts().head(10).plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
my_series=pd.Series([3,3,4,32,314,332])
my_series.index=pd.RangeIndex(start=0,step=2, stop=12)
my_series.index
# Out:
# RangeIndex(start=0, stop=12, step=2)

# %%
my_series
# Out:
# 0       3
# 2       3
# 4       4
# 6      32
# 8     314
# 10    332
# dtype: int64

# %%
my_series_2=pd.Series([2,3,4,5],index=['a','b','c','d'])

# %%
my_series_2
# Out:
# a    2
# b    3
# c    4
# d    5
# dtype: int64

# %%
#mengganti index
my_series_2.index=['d','b','c','a']

# %%
my_series_2
# Out:
# d    2
# b    3
# c    4
# a    5
# dtype: int64

# %%
my_series_3=pd.Series({'a':1,'b':2,'c':3,'d':4})
my_series_3.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
my_series_3.name='try pandas'
my_series_3.index.name='alfa'
my_series_3
# Out:
# alfa
# a    1
# b    2
# c    3
# d    4
# Name: try pandas, dtype: int64

# %%
#membuat series dengan tanggal
range=pd.date_range('07/09/2021',periods=60, freq='W')
valueluw=np.random.random([60])
myDateSeries=pd.Series(valueluw, index=range)
myDateSeries
# Out:
# 2021-07-11    0.590166
# 2021-07-18    0.730512
# 2021-07-25    0.228677
# 2021-08-01    0.355397
# 2021-08-08    0.009590
# 2021-08-15    0.208072
# 2021-08-22    0.931484
# 2021-08-29    0.980601
# 2021-09-05    0.209136
# 2021-09-12    0.494738
# 2021-09-19    0.581778
# 2021-09-26    0.256947
# 2021-10-03    0.627763
# 2021-10-10    0.444123
# 2021-10-17    0.307330
# 2021-10-24    0.759523
# 2021-10-31    0.150444
# 2021-11-07    0.484703
# 2021-11-14    0.410656
# 2021-11-21    0.369442
# 2021-11-28    0.986903
# 2021-12-05    0.462964
# 2021-12-12    0.381418
# 2021-12-19    0.534613
# 2021-12-26    0.532790
# 2022-01-02    0.677421
# 2022-01-09    0.959793
# 2022-01-16    0.338448
# 2022-01-23    0.068251
# 2022-01-30    0.432701
# 2022-02-06    0.735391
# 2022-02-13    0.940250
# 2022-02-20    0.929569
# 2022-02-27    0.378726
# 2022-03-06    0.667511
# 2022-03-13    0.468525
# 2022-03-20    0.669389
# 2022-03-27    0.332982
# 2022-04-03    0.454343
# 2022-04-10    0.821018
# ...

# %%
filteredData=myDateSeries[myDateSeries>=0.5]
filteredData.plot()
# Out:
# <AxesSubplot:>

# %%
#DataFrame
studentDataFrame=pd.DataFrame({
    "name":['ego','munaroh','fatimah'],
            'age':[21,21,25],
            'ipk':[3.0,3.1,2.75],
            'sks':[80,100,77]})
studentDataFrame
# Out:
#       name  age   ipk  sks
# 0      ego   21  3.00   80
# 1  munaroh   21  3.10  100
# 2  fatimah   25  2.75   77

# %%
studentDataFrame.filter(items=['name','ipk'],axis='columns')
# Out:
#       name   ipk
# 0      ego  3.00
# 1  munaroh  3.10
# 2  fatimah  2.75

# %%
studentDataFrame['kredit']=studentDataFrame['sks']*studentDataFrame['ipk']

# %%
studentDataFrame
# Out:
#       name  age   ipk  sks  kredit
# 0      ego   21  3.00   80  240.00
# 1  munaroh   21  3.10  100  310.00
# 2  fatimah   25  2.75   77  211.75

# %%
studentDataFrame[studentDataFrame.kredit>220]
# Out:
#       name  age  ipk  sks  kredit
# 0      ego   21  3.0   80   240.0
# 1  munaroh   21  3.1  100   310.0

# %%
studentDataFrame.rename(columns={'kredit':'total'})
# Out:
#       name  age   ipk  sks   total
# 0      ego   21  3.00   80  240.00
# 1  munaroh   21  3.10  100  310.00
# 2  fatimah   25  2.75   77  211.75

# %%
studentDataFrame.append({'name':'helenna','age':21,
                         'ipk':3.4,'sks':120}, ignore_index=True)
# Out:
#       name  age   ipk  sks  kredit
# 0      ego   21  3.00   80  240.00
# 1  munaroh   21  3.10  100  310.00
# 2  fatimah   25  2.75   77  211.75
# 3  helenna   21  3.40  120     NaN

# %%
studentDataFrame.filter(regex='^m', axis=0)
# Out:
# Empty DataFrame
# Columns: [name, age, ipk, sks, kredit]
# Index: []

# %%
studentDataFrame[studentDataFrame.name.str.contains('oh$')]
# Out:
#       name  age  ipk  sks  kredit
# 1  munaroh   21  3.1  100   310.0

# %%
pd.set_option('display.precision',2)

# %%
movieDB=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
movieDB
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movieDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
movieDB.describe()
# Out:
#        star_rating  duration
# count       979.00    979.00
# mean          7.89    120.98
# std           0.34     26.22
# min           7.40     64.00
# 25%           7.60    102.00
# 50%           7.80    117.00
# 75%           8.10    134.00
# max           9.30    242.00

# %%
#filter film dengan duration>100, star_rating>7
filterFilm=movieDB[(movieDB['duration']<=100)&
        (movieDB['star_rating']>7)]
filterFilm
# Out:
#      star_rating                                              title  \
# 5            8.9                                       12 Angry Men
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 55           8.5                                      The Lion King
# ..           ...                                                ...
# 957          7.4                        National Lampoon's Vacation
# 959          7.4                               Deconstructing Harry
# 962          7.4                                 Driving Miss Daisy
# 966          7.4                                 The Simpsons Movie
# 971          7.4                                 Death at a Funeral
#
#     content_rating      genre  duration  \
# 5        NOT RATED      Drama        96
# 29          PASSED     Comedy        87
# ...

# %%
#urutkan dari rating tertinggi
filterFilm.sort_values('star_rating')
# Out:
#      star_rating                                              title  \
# 971          7.4                                 Death at a Funeral
# 933          7.4                                        Beetlejuice
# 938          7.4                                Alice in Wonderland
# 939          7.4                                     Predestination
# 942          7.4                                    Raising Arizona
# ..           ...                                                ...
# 55           8.5                                      The Lion King
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 35           8.6                                       Modern Times
# 29           8.6                                        City Lights
# 5            8.9                                       12 Angry Men
#
#     content_rating      genre  duration  \
# 971              R     Comedy        90
# 933             PG     Comedy        92
# ...

# %%
filterFilm['star_rating'].max()
# Out:
# 8.9

# %%
filterFilm.sort_values('star_rating',ascending=False)
# Out:
#      star_rating                                              title  \
# 5            8.9                                       12 Angry Men
# 35           8.6                                       Modern Times
# 29           8.6                                        City Lights
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 55           8.5                                      The Lion King
# ..           ...                                                ...
# 943          7.4                                    The Bucket List
# 942          7.4                                    Raising Arizona
# 939          7.4                                     Predestination
# 933          7.4                                        Beetlejuice
# 971          7.4                                 Death at a Funeral
#
#     content_rating      genre  duration  \
# 5        NOT RATED      Drama        96
# 35               G     Comedy        87
# ...

# %%
import re
movieDB[movieDB.title.str.contains('^S', flags=re.IGNORECASE)]
# Out:
#      star_rating                                           title  \
# 8            8.9                                Schindler's List
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 17           8.7                                   Seven Samurai
# 19           8.7                                       Star Wars
# 24           8.7                                           Se7en
# ..           ...                                             ...
# 904          7.5  Sweeney Todd: The Demon Barber of Fleet Street
# 912          7.5                                           Smoke
# 913          7.5                                        Suspiria
# 929          7.5                                 Say Anything...
# 951          7.4                                   Sleepy Hollow
#
#     content_rating      genre  duration  \
# 8                R  Biography       195
# 12              PG     Action       124
# 17         UNRATED      Drama       207
# ...

# %%
pd.set_option('display.precision',2)

# %%
groupMovie= movieDB.groupby('genre')['title']
groupMovie.describe()
# Out:
#           count unique                              top freq
# genre
# Action      136    136                           Aliens    1
# Adventure    75     74                        True Grit    2
# Animation    62     62                          Paprika    1
# Biography    77     77                    The Hurricane    1
# Comedy      156    156          Crimes and Misdemeanors    1
# Crime       124    123  The Girl with the Dragon Tattoo    2
# Drama       278    278                        The Hours    1
# Family        2      2       E.T. the Extra-Terrestrial    1
# Fantasy       1      1        The City of Lost Children    1
# Film-Noir     3      3                            Laura    1
# History       1      1              Battleship Potemkin    1
# Horror       29     28                          Dracula    2
# Mystery      16     16                   Twelve Monkeys    1
# Sci-Fi        5      5                           Brazil    1
# ...

# %%
summary=movieDB.pivot_table(index=['genre'], 
                            values=['duration','star_rating'],
                           aggfunc={'duration':'mean',
                                   'star_rating':'mean'})

# %%
summary.plot.bar('duration')
# Out:
# <AxesSubplot:xlabel='duration'>

# %%
summary.plot.bar('star_rating')
# Out:
# <AxesSubplot:xlabel='star_rating'>

# %%
filterFilm.dropna()
# Out:
#      star_rating                                              title  \
# 5            8.9                                       12 Angry Men
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 55           8.5                                      The Lion King
# ..           ...                                                ...
# 957          7.4                        National Lampoon's Vacation
# 959          7.4                               Deconstructing Harry
# 962          7.4                                 Driving Miss Daisy
# 966          7.4                                 The Simpsons Movie
# 971          7.4                                 Death at a Funeral
#
#     content_rating      genre  duration  \
# 5        NOT RATED      Drama        96
# 29          PASSED     Comedy        87
# ...
